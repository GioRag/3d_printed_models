# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from IPython.display import Image

STATUS_OK = 0
STATUS_ERROR = -1

# %%
def saveModel(model, filePath):
    pickle.dump(model, open(filePath, 'w'))

def loadModel(filePath):
    return pickle.load(open(filePath,'r'))

# %% [markdown]
# # Mechanical testing of different elastomeric tubes
# ![Bose electroForce tester](images/Bose_tester.png)

# %% [markdown]
# ## BK100_58C_15min
#
# ![BK 58C 15 min post-processing](images/20170411_134732.jpg)
#
# ### Stress-strain curve
# ![BK 58C 15 min post-processing](BK100_58C_15min\BK100_58C_15min.png)

# %%
def aver_BK100_58C_15min():
    fileName_01 = "./BK100_58C_15min/BK100_58C_15min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK100_58C_15min/BK100_58C_15min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK100_58C_15min/BK100_58C_15min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./BK100_58C_15min/BK100_58C_15min_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.045)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("aver_BK100_58C_15min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

aver_BK100_58C_15min()

# %% [markdown]
# ## BK100_60C_35min
#
# ![BK 60C 35 min post-processing](images/20170411_140730.jpg)
#
# ### Stress-strain curve
# ![BK 60C 35 min post-processing](BK100_60C_35min\BK100_60C_35min.png)
#
#  * _Notes_
#  Notice that the sample number 2 and 3 have some wax remained in the lumen.

# %%
def aver_BK100_60C_35min():
    fileName_01 = "./BK100_60C_35min/BK100_60C_35min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK100_60C_35min/BK100_60C_35min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK100_60C_35min/BK100_60C_35min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    fileName_04 = "./BK100_60C_35min/BK100_60C_35min_4.pkl"
    ss_data_04 = loadModel(fileName_04)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_04.shape[0]]))
    min_len_ = np.min(np.array([ss_data_02.shape[0], ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len]  + ss_data_04[0:min_len, 0:min_len]) / 2.)
    ss_data_aver_ = ((ss_data_02[0:min_len_, 0:min_len_]  + ss_data_03[0:min_len_, 0:min_len_]) / 2.)
    
    saveModel(ss_data_aver, "./BK100_60C_35min/BK100_60C_35min_avrg_1.pkl")
    saveModel(ss_data_aver_, "./BK100_60C_35min/BK100_60C_35min_avrg_2.pkl")
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    mins_ = np.zeros(min_len_)
    maxes_ = np.zeros(min_len_)
    means_ = np.zeros(min_len_)
    stds_ = np.zeros(min_len_)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_04[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_04[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_04[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_04[i, 1]])
    for i in range(min_len_):
        mins_[i] = np.min([ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes_[i] = np.max([ss_data_02[i, 1], ss_data_03[i, 1]])
        means_[i] = np.mean([ss_data_02[i, 1], ss_data_03[i, 1]])
        stds_[i] = np.std([ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
#     ax.scatter(ss_data_04[0:min_len, 0], ss_data_04[0:min_len, 1], alpha=0.15, c='c', marker='o',
#                s=15, label='sample no 4')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean 1,4')
    ax.plot(ss_data_aver_[:, 0], ss_data_aver_[:, 1], "y", label='Mean 2, 3 (Wax)')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    ax.errorbar(ss_data_aver_[0::5, 0], means_[0::5], stds_[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver_[0::5, 0], means_[0::5], [means_[0::5] - mins_[0::5],
                maxes_[0::5] - means_[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.07)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("aver_BK100_60C_35min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

aver_BK100_60C_35min()

# %% [markdown]
# ## BK100_55C_60min
#
# ![BK 55C 60 min post-processing](images/20170411_140010.jpg)
#
# ### Stress-strain curve
# ![BK 55C 60 min post-processing](BK100_55C_60min\BK100_55C_60min.png)

# %%
def aver_BK100_55C_60min():
    fileName_01 = "./BK100_55C_60min/BK100_55C_60min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK100_55C_60min/BK100_55C_60min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK100_55C_60min/BK100_55C_60min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./BK100_55C_60min/BK100_55C_60min_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.045)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("aver_BK100_55C_60min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

aver_BK100_55C_60min()

# %% [markdown]
# ## BK100_60C_45min
# ![BK 60C 45 min post-processing](images/20170411_125650.jpg)
# ### BK100_60C_45min
# ![BK 60C 45 min post-processing](BK100_60C_45min/BK100_60C_45min.png)

# %%
def BK100_60C_45min():
    fileName_01 = "./BK100_60C_45min/BK100_60C_45min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK100_60C_45min/BK100_60C_45min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK100_60C_45min/BK100_60C_45min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./BK100_60C_45min/BK100_60C_45min_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.065)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("BK100_60C_45min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()
    
    return STATUS_OK

BK100_60C_45min()
# Out:
# 0

# %% [markdown]
# ## BK500_60C_15min
# ![BK500 60C 15 min post-processing](images/20170411_143611.jpg)
# ### BK500_60C_15min
# ![BK500 60C 15 min post-processing](BK500_60C_15min/BK500_60C_15min.png)

# %%
def BK500_60C_15min():
    fileName_01 = "./BK500_60C_15min/BK500_60C_15min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK500_60C_15min/BK500_60C_15min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK500_60C_15min/BK500_60C_15min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./BK500_60C_15min/BK500_60C_15min_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 1.5)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("BK500_60C_15min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return STATUS_OK

BK500_60C_15min()
# Out:
# 0

# %% [markdown]
# ## BK_600_60C_15min
# ![BK600 60C 15 min post-processing](images/20170411_142819.jpg)
# ### BK600_60C_15min
# ![BK600 60C 15 min post-processing](BK_600_60C_15min/BK_600_60C_15min.png)

# %%
def BK_600_60C_15min():
    fileName_01 = "./BK_600_60C_15min/BK_600_60C_15min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK_600_60C_15min/BK_600_60C_15min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK_600_60C_15min/BK_600_60C_15min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./BK_600_60C_15min/BK_600_60C_15min_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.4)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("BK_600_60C_15min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return STATUS_OK

BK_600_60C_15min()
# Out:
# 0

# %% [markdown]
# ## BK_700_60C_15min
# ![BK700 60C 15 min post-processing](images/20170411_141818.jpg)
# ### BK700_60C_15min
# ![BK700 60C 15 min post-processing](BK_700_60C_15min/BK_700_60C_15min.png)

# %%
def BK_700_60C_15min():
    fileName_01 = "./BK_700_60C_15min/BK_700_60C_15min_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./BK_700_60C_15min/BK_700_60C_15min_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./BK_700_60C_15min/BK_700_60C_15min_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./BK_700_60C_15min/BK_700_60C_15min_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.11)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("BK_700_60C_15min")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return STATUS_OK

BK_700_60C_15min()
# Out:
# 0

# %% [markdown]
# ## Commercial tubes
#
# ![Commercial tubes](images/20170411_145741.jpg)

# %% [markdown]
# ### Cole Palmer
#
# ![Cole-Palmer](ColePalmer/cole_palmer_tubes.png)

# %%
def cole_palmer():
    fileName_01 = "./ColePalmer/ColePalmer_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./ColePalmer/ColePalmer_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./ColePalmer/ColePalmer_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    fileName_04 = "./ColePalmer/ColePalmer_4.pkl"
    ss_data_04 = loadModel(fileName_04)    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0], ss_data_04.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len] + ss_data_04[0:min_len, 0:min_len]) / 4.)
    saveModel(ss_data_aver, "./ColePalmer/ColePalmer_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.7)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("Cole Palmer")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return STATUS_OK

cole_palmer()
# Out:
# 0

# %% [markdown]
# ### Silex
#
# ![Silex](Silex/Silex.png)

# %%
def silex():
    fileName_01 = "./Silex/Silex_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./Silex/Silex_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./Silex/Silex_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    fileName_04 = "./Silex/Silex_4.pkl"
    ss_data_04 = loadModel(fileName_04)    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0], ss_data_04.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len] + ss_data_04[0:min_len, 0:min_len]) / 4.)
    saveModel(ss_data_aver, "./Silex/Silex_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1], ss_data_04[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 0.85)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("Silex")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return STATUS_OK

silex()
# Out:
# 0

# %% [markdown]
# ### Tygon
#
# ![Tygon](Tygon/Tygon.png)

# %%
def Tygon():
    fileName_01 = "./Tygon/Tygon_1.pkl"
    ss_data_01 = loadModel(fileName_01)
    fileName_02 = "./Tygon/Tygon_2.pkl"
    ss_data_02 = loadModel(fileName_02)
    fileName_03 = "./Tygon/Tygon_3.pkl"
    ss_data_03 = loadModel(fileName_03)
    
    # min length of arrays
    min_len = np.min(np.array([ss_data_01.shape[0], ss_data_02.shape[0],
                               ss_data_03.shape[0]]))
    # average
    ss_data_aver = ((ss_data_01[0:min_len, 0:min_len] + ss_data_02[0:min_len, 0:min_len] +
                     ss_data_03[0:min_len, 0:min_len]) / 3.)
    saveModel(ss_data_aver, "./Tygon/Tygon_avrg.pkl")
    
    # min, max, mean, sd
    # allocate memory
    mins = np.zeros(min_len)
    maxes = np.zeros(min_len)
    means = np.zeros(min_len)
    stds = np.zeros(min_len)
    for i in range(min_len):
        mins[i] = np.min([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        maxes[i] = np.max([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        means[i] = np.mean([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
        stds[i] = np.std([ss_data_01[i, 1], ss_data_02[i, 1], ss_data_03[i, 1]])
 
    # --- PLOT --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
#     ax.scatter(ss_data_01[0:min_len, 0], ss_data_01[0:min_len, 1], alpha=0.15, c='b', marker='o',
#                s=15, label='sample no 1')
#     ax.scatter(ss_data_02[0:min_len, 0], ss_data_02[0:min_len, 1], alpha=0.15, c='y', marker='o',
#                s=15, label='sample no 2')
#     ax.scatter(ss_data_03[0:min_len, 0], ss_data_03[0:min_len, 1], alpha=0.15, c='m', marker='o',
#                s=15, label='sample no 3')
    ax.plot(ss_data_aver[:, 0], ss_data_aver[:, 1], "r", label='Mean')
    # create stacked errorbars:
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], stds[0::5], fmt='ok', lw=3)
    ax.errorbar(ss_data_aver[0::5, 0], means[0::5], [means[0::5] - mins[0::5],
                maxes[0::5] - means[0::5]],
                fmt=".k", ecolor='gray', lw=1)
    
    ax.set_xlim(0, 0.2)
    ax.set_ylim(0, 1.2)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=2, fancybox=True,
               shadow=True)
    plt.title("Tygon")
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return STATUS_OK

Tygon()
# Out:
# 0

# %% [markdown]
# ### Dragon Skin
#
# ![Dragon-Skin](DragonSkin/dragonSkin.png)

# %% [markdown]
# ## Comparison of different tubes

# %%
def bool_compare(strarr_filename, str_title, doublearr_invivo=None):
    len_input = len(strarr_filename)
    colours_ = ['b', 'r', 'g', 'm', 'c', 'k', 'y', 'darkkhaki', 'olive', 'orange', 'violet', 'gold']
    
    # --- Fig --- #
    fig = plt.figure(figsize=(10, 10), facecolor='w', edgecolor='k',
                     linewidth=2.0, frameon=True)
    ax = fig.add_subplot(1, 1, 1)
    y_max = 0.
    for i in range(len_input):
        model = loadModel(strarr_filename[i])
        fileName = strarr_filename[i].split('//')[-1]
        model_strain = model[:, 0]
        model_stress = model[:, 1]
        if y_max < np.max(model_stress):
            y_max = np.max(model_stress)
        # plot stress-strain values
        ax.plot(model_strain, model_stress, colours_[i], label=fileName)
        
    if doublearr_invivo is not None:
        ax.plot(doublearr_invivo[:, 0], doublearr_invivo[:, 1], 'k^--',
                label="in vivo")
        
    ax.set_xlim(0, 0.4)
    ax.set_ylim(0, y_max)
    ax.set_xlabel("$\epsilon_e$")
    ax.set_ylabel("$\sigma_e$ (MPa)")
    plt.legend(loc="upper left", scatterpoints=1, ncol=1, fancybox=True,
               shadow=True)
    plt.title(str_title)
#    plt.savefig(_fileName[0] + '.png')
    plt.show()

    return True

# %%
def int_compare_invitro():
    fileNames = ["./BK100_55C_60min/BK100_55C_60min_avrg.pkl", "./BK100_58C_15min/BK100_58C_15min_avrg.pkl", 
                 "./BK100_60C_35min/BK100_60C_35min_avrg_1.pkl", "./BK100_60C_35min/BK100_60C_35min_avrg_2.pkl",
                 "./BK100_60C_45min/BK100_60C_45min_avrg.pkl", "./BK500_60C_15min/BK500_60C_15min_avrg.pkl",
                 "./BK_600_60C_15min/BK_600_60C_15min_avrg.pkl", "./BK_700_60C_15min/BK_700_60C_15min_avrg.pkl",
                 "ColePalmer/ColePalmer_avrg.pkl", "./Silex/Silex_avrg.pkl", "./Tygon/Tygon_avrg.pkl",
                 "DragonSkin/DragonSkin_1.pkl"]
    fileNames_ = ["./BK100_55C_60min/BK100_55C_60min_avrg.pkl", "./BK100_58C_15min/BK100_58C_15min_avrg.pkl", 
                  "./BK100_60C_35min/BK100_60C_35min_avrg_1.pkl", "./BK100_60C_35min/BK100_60C_35min_avrg_2.pkl",
                  "./BK100_60C_45min/BK100_60C_45min_avrg.pkl"]
    
    res = bool_compare(fileNames_, "$100\%$ elastomeric material")
    
    res = bool_compare(fileNames, "All the tested tubes")
    
    return STATUS_OK

# %%
int_compare_invitro()
# Out:
# 0

# %% [markdown]
# ## Comparison of tested tubes against in vivo data

# %% [markdown]
# ### In vivo data taken from [Stiffness of Carotid Artery Wall Material and Blood Pressure in Humans](http://stroke.ahajournals.org/content/31/3/782)

# %%
def int_compare_invivo(strarr_files, dbarr_data, str_title):

    res = bool_compare(strarr_files, str_title, dbarr_data)
        
    return STATUS_OK

# %%
fileNames = ["./BK100_55C_60min/BK100_55C_60min_avrg.pkl", "./BK100_58C_15min/BK100_58C_15min_avrg.pkl", 
             "./BK100_60C_35min/BK100_60C_35min_avrg_1.pkl", "./BK100_60C_35min/BK100_60C_35min_avrg_2.pkl",
             "./BK100_60C_45min/BK100_60C_45min_avrg.pkl"]
# data taken from http://stroke.ahajournals.org/content/31/3/782, fig 1
db_radial_data = np.array([[0., 0.], [0.025, 6.], [0.05, 7.5], [0.1, 9.5], [0.15, 11.],
                          [0.2, 14.], [0.25, 18.5], [0.3, 25.], [0.35, 31.5],
                          [0.4, 43.5]])
db_radial_data[:, 1] = db_radial_data[:, 1]*0.001
int_compare_invivo(fileNames, db_radial_data,
                   "$100\%$ elastomeric material vs Radial")
# Out:
# 0

# %% [markdown]
# ### In vivo data taken from [Comparison of Mechanical Properties of Human Ascending Aorta and Aortic Sinuses](http://www.sciencedirect.com/science/article/pii/S0003497511019205)

# %%
fileNames = ["./BK100_55C_60min/BK100_55C_60min_avrg.pkl", "./BK100_58C_15min/BK100_58C_15min_avrg.pkl", 
             "./BK100_60C_35min/BK100_60C_35min_avrg_1.pkl", "./BK100_60C_35min/BK100_60C_35min_avrg_2.pkl",
             "./BK100_60C_45min/BK100_60C_45min_avrg.pkl"]
# data taken from http://www.sciencedirect.com/science/article/pii/S0003497511019205,
# fig 3.
db_Asce_Aorta_data = np.array([[0., 0.], [0.05, 11.], [0.1, 31.], [0.15, 60.],
                               [0.2, 110], [0.25, 190.]])
db_Asce_Aorta_data[:, 1] = db_Asce_Aorta_data[:, 1]*0.001
int_compare_invivo(fileNames, db_Asce_Aorta_data,
                   "$100\%$ elastomeric material vs Ascending Aorta")
# Out:
# 0

# %%
# commercial tubes
fileNames_ct = [ "ColePalmer/ColePalmer_avrg.pkl", 
                "./Silex/Silex_avrg.pkl",
                "./Tygon/Tygon_avrg.pkl"]
# data taken from http://www.sciencedirect.com/science/article/pii/S0003497511019205,
# fig 3.
db_Asce_Aorta_data = np.array([[0., 0.], [0.05, 11.], [0.1, 31.], [0.15, 60.],
                               [0.2, 110], [0.25, 190.]])
db_Asce_Aorta_data[:, 1] = db_Asce_Aorta_data[:, 1]*0.001
int_compare_invivo(fileNames_ct, db_Asce_Aorta_data,
                   "Commercial tubes vs Ascending Aorta")
# Out:
# 0

# %%
from IPython.core.display import HTML
css_file = './styles/custom.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
# ...
